# %%
import requests

# URL de ton endpoint FastAPI
url = "http://127.0.0.1:8000/predict"

# Exemple avec des films spécifiques
payload = {"user_id": 1}

# Requête POST
response = requests.post(url, json=payload)

# Afficher la réponse JSON
print(response.json())
# Out:
# {'user_id': 1, 'top_recommendations': [{'movie_id': 923.0, 'title': 'Citizen Kane (1941)', 'predicted_rating': 4.65}, {'movie_id': 1172.0, 'title': 'Cinema Paradiso (Nuovo cinema Paradiso) (1989)', 'predicted_rating': 4.37}, {'movie_id': 3000.0, 'title': 'Princess Mononoke (Mononoke-hime) (1997)', 'predicted_rating': 4.33}, {'movie_id': 745.0, 'title': 'Wallace & Gromit: A Close Shave (1995)', 'predicted_rating': 4.3}, {'movie_id': 1212.0, 'title': 'Third Man, The (1949)', 'predicted_rating': 4.28}]}

# %%
import pandas as pd
response = requests.post(url, json=payload)
data = response.json()

# Transformer en DataFrame
top_reco_df = pd.DataFrame(data["top_recommendations"])
print(top_reco_df)
# Out:
#    movie_id                                           title  predicted_rating
# 0     923.0                             Citizen Kane (1941)              4.65
# 1    1172.0  Cinema Paradiso (Nuovo cinema Paradiso) (1989)              4.37
# 2    3000.0        Princess Mononoke (Mononoke-hime) (1997)              4.33
# 3     745.0          Wallace & Gromit: A Close Shave (1995)              4.30
# 4    1212.0                           Third Man, The (1949)              4.28

# %%
top_reco_df = top_reco_df.sort_values(by="predicted_rating", ascending=False)[["title", "predicted_rating"]]
print(top_reco_df)
# Out:
#                                             title  predicted_rating
# 0                             Citizen Kane (1941)              4.65
# 1  Cinema Paradiso (Nuovo cinema Paradiso) (1989)              4.37
# 2        Princess Mononoke (Mononoke-hime) (1997)              4.33
# 3          Wallace & Gromit: A Close Shave (1995)              4.30
# 4                           Third Man, The (1949)              4.28

# %%
import requests

url = "http://127.0.0.1:8000/predict"

# Exemple : utilisateur 1 qui a noté certains films
payload = {
    "user_id": 1,
    "movie_ids": [1, 50, 100]  # films que l'utilisateur a vus / notés
}

response = requests.post(url, json=payload)

# Vérifier le status
print("STATUS CODE:", response.status_code)

# Afficher la réponse JSON si OK
if response.status_code == 200:
    print(response.json())
else:
    print("Erreur :", response.text)
# Out:
# STATUS CODE: 200
# {'user_id': 1, 'predictions': [{'movie_id': 1, 'title': 'Toy Story (1995)', 'predicted_rating': 3.83}, {'movie_id': 50, 'title': 'Usual Suspects, The (1995)', 'predicted_rating': 4.46}, {'movie_id': 100, 'title': 'City Hall (1996)', 'predicted_rating': 3.08}]}

# %%
# Obtenir top-N après mise à jour
payload_topn = {"user_id": 1}  # juste l'utilisateur, pas de films spécifiques
response_topn = requests.post(url, json=payload_topn)
print(response_topn.json())
# Out:
# {'user_id': 1, 'top_recommendations': [{'movie_id': 923.0, 'title': 'Citizen Kane (1941)', 'predicted_rating': 4.65}, {'movie_id': 1172.0, 'title': 'Cinema Paradiso (Nuovo cinema Paradiso) (1989)', 'predicted_rating': 4.37}, {'movie_id': 3000.0, 'title': 'Princess Mononoke (Mononoke-hime) (1997)', 'predicted_rating': 4.33}, {'movie_id': 745.0, 'title': 'Wallace & Gromit: A Close Shave (1995)', 'predicted_rating': 4.3}, {'movie_id': 1212.0, 'title': 'Third Man, The (1949)', 'predicted_rating': 4.28}]}

# %%
# Transformer en DataFrame
import pandas as pd
data = response_topn.json()

# Transformer en DataFrame
top_reco_df = pd.DataFrame(data["top_recommendations"])
print(top_reco_df)
# Out:
#    movie_id                                           title  predicted_rating
# 0     923.0                             Citizen Kane (1941)              4.65
# 1    1172.0  Cinema Paradiso (Nuovo cinema Paradiso) (1989)              4.37
# 2    3000.0        Princess Mononoke (Mononoke-hime) (1997)              4.33
# 3     745.0          Wallace & Gromit: A Close Shave (1995)              4.30
# 4    1212.0                           Third Man, The (1949)              4.28
