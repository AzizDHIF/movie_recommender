# %%
import requests

# URL de ton endpoint FastAPI
url = "http://127.0.0.1:8000/predict"

# Exemple avec des films spécifiques
payload = {"user_id": 1}

# Requête POST
response = requests.post(url, json=payload)

# Afficher la réponse JSON
print(response.json())
# Out:
# {'user_id': 1, 'num_ratings': 95, 'recommendation_strategy': 'personalized', 'recommendations': [{'movie_id': 923, 'title': 'Citizen Kane (1941)', 'predicted_rating': 4.35}, {'movie_id': 1172, 'title': 'Cinema Paradiso (Nuovo cinema Paradiso) (1989)', 'predicted_rating': 4.24}, {'movie_id': 1196, 'title': 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'predicted_rating': 4.23}, {'movie_id': 745, 'title': 'Wallace & Gromit: A Close Shave (1995)', 'predicted_rating': 4.18}, {'movie_id': 2329, 'title': 'American History X (1998)', 'predicted_rating': 4.15}]}

# %%
import pandas as pd
response = requests.post(url, json=payload)
data = response.json()

# Transformer en DataFrame
top_reco_df = pd.DataFrame(data["recommendations"])
print(top_reco_df)
# Out:
#    movie_id                                              title  \
# 0       923                                Citizen Kane (1941)
# 1      1172     Cinema Paradiso (Nuovo cinema Paradiso) (1989)
# 2      1196  Star Wars: Episode V - The Empire Strikes Back...
# 3       745             Wallace & Gromit: A Close Shave (1995)
# 4      2329                          American History X (1998)
#
#    predicted_rating
# 0              4.35
# 1              4.24
# 2              4.23
# 3              4.18
# 4              4.15

# %%
top_reco_df = top_reco_df.sort_values(by="predicted_rating", ascending=False)[["title", "predicted_rating"]]
print(top_reco_df)
# Out:
#                                                title  predicted_rating
# 0                                Citizen Kane (1941)              4.35
# 1     Cinema Paradiso (Nuovo cinema Paradiso) (1989)              4.24
# 2  Star Wars: Episode V - The Empire Strikes Back...              4.23
# 3             Wallace & Gromit: A Close Shave (1995)              4.18
# 4                          American History X (1998)              4.15
